# %%
# Data structure

# %% [markdown]
# 1. What are data structures, and why are they important?
# - Data structures are formats for organizing, storing, processing, and retrieving data.
# - Data structures make it easier to manage large amounts of data.   - Data structures help make code more efficient.
# - Learning data structures helps you develop problem-solving techniques that can be applied to new frameworks.
#
# 2. Explain the difference between mutable and immutable data types with examples.
# - Mutable data types can be changed after they are created, while immutable data types cannot.
# -  **mutable data types **
#     - Lists: Elements can be added, removed, or changed
#     - Dictionaries: Values can be changed
#     - Sets: Values can be changed
# -** immutable data types **
#     - Strings: Content cannot be changed after creation
#     - Tuples: Elements cannot be changed, added, removed, or replaced
#     -Integers: Values cannot be changed
#     -Floats: Values cannot be changed
#
# 3 What are the main differences between lists and tuples in Python?
#  - The main difference between lists and tuples in Python is that lists are mutable, while tuples are immutable.
#
# 4. Describe how dictionaries store data.
# - The dictionary consists of a number of buckets. Each of these buckets contains the hash code of the object that contains the key-value pair. A pointer to the key object and a pointer to the value object.
#
# 5. Why might you use a set instead of a list in Python?
# - By definition, sets cannot contain duplicates
# - Processing speed matters.
#
# 6. What is a string in Python, and how is it different from a list?
# - A string is a sequence of characters between single or double quotes. A list is a sequence of items, where each item could be anything
#
# 7. How do tuples ensure data integrity in Python?
# - Tuples are immutable to ensure that their contents remain constant throughout their lifecycle, guaranteeing data integrity and reliability.
# - This immutability allows tuples to be used as keys in dictionaries and elements in sets, as they can be hashed
#
# 8. What is a hash table, and how does it relate to dictionaries in Python?
# - In Python, a hash table is a data structure that's used to implement dictionaries.
# - A hash table stores key-value pairs, and the dictionary data type in Python uses a hash table to store its key-value pairs.
#
# 9. Can lists contain different data types in Python?
# - Yes,a list can also contain a mix of Python types including strings, floats, and booleans.
#
# 10. Explain why strings are immutable in Python.
# - they cannot be changed after they are created since strings can't be changed, we construct *new* strings as we go to represent computed values.
#
# 11. What advantages do dictionaries offer over lists for certain tasks?
# -  when you need to quickly look up a specific value based on a unique key, as dictionaries use a hash table to enable fast access to data using that key, making them ideal for tasks requiring rapid lookups or mapping between related data points, unlike lists which require sequential searching through elements to find a match.
#
# 12. Describe a scenario where using a tuple would be preferable over a list.
# - Use a list if you need a mutable collection of items where you may need to add, remove, or change elements.
# - Use a tuple if you need an immutable collection where the elements won't change after creation.
#
# 13. How do sets handle duplicate values in Python?
# - Items of a set in python are immutable (unchangeable), do not duplicate values, and unordered.
#
# 14. How does the “in” keyword work differently for lists and dictionaries?
# -  The in operation for the dictionary tests on keys.
# -The key of the dictionary is a unique value as well as the set, and the execution time is about the same as for sets.
# - On the other hand, dictionary values can be duplicated like a list.
#
# 15. Can you modify the elements of a tuple? Explain why or why not.
# - No, you cannot modify the elements of a tuple because tuples are "immutable" in most programming languages, meaning once created, their elements cannot be changed, added, or removed; attempting to alter a tuple element will result in an error message.
#
# 16. What is a nested dictionary, and give an example of its use case?
# - A nested dictionary is a data structure where a dictionary itself is used as a value within another dictionary, essentially creating a hierarchy of key-value pairs within a dictionary
# -  Representing complex data with multiple levels of organization, like storing employee information by department, where each department is a key in the outer dictionary and its employees' details are nested dictionaries within it.
#
# 17. Describe the time complexity of accessing elements in a dictionary.
# - The time complexity of accessing an element in a Python dictionary is (O(1)), which means it's very fast. This is because dictionaries use a hash table internally, which allows for constant time lookup.
#
# 18. In what situations are lists preferred over dictionaries?
# - If you need an ordered collection, like a sequence of user actions, lists are your go-to.
# - On the other hand, when you need quick look-ups, like mapping usernames to user data, dictionaries are invaluable.
#
# 19. Why are dictionaries considered unordered, and how does that affect data retrieval?
# - Because you dont pull info out based on index like lists.
# -  The items do not have a defined order, you cannot refer to an item by using an index.
# 20. Explain the difference between a list and a dictionary in terms of data retrieval.
# - A list retrieves data using its index position (numerical order), while a dictionary retrieves data using a unique key, allowing for direct access to specific values based on their associated key, making dictionary lookups generally faster for large datasets when you need to find a specific piece of information quickly.

# %%
#1 Write a code to create a string with your name and print it
name = "Priyanka Pal"
print(name)
# Out:
# Priyanka Pal

# %%
#2 Write a code to find the length of the string "Hello World"
le = "Hello World"
len(le)
# Out:
# 11

# %%
#3 Write a code to slice the first 3 characters from the string "Python Programming".
te = "Python Programming"
te_slice = te[:3]
print(te_slice)
# Out:
# Pyt

# %%
#4 Write a code to convert the string "hello" to uppercase.
text = "hello"
uppercase_text = text.upper()
print(uppercase_text)
# Out:
# HELLO

# %%
#5 Write a code to replace the word "apple" with "orange" in the string "I like apple".
text = "I like apple"
updated_text = text.replace("apple", "orange")
print(updated_text)
# Out:
# I like orange

# %%
#6 Write a code to create a list with numbers 1 to 5 and print it
numbers = [1, 2, 3, 4, 5]
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
#7Write a code to append the number 10 to the list [1, 2, 3, 4]
numbers = [1, 2, 3, 4]
numbers.append(10)
print(numbers)
# Out:
# [1, 2, 3, 4, 10]

# %%
#8 Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]
listt = [1,2,3,4,5]
listt.remove(3)
listt
# Out:
# [1, 2, 4, 5]

# %%
#9 Write a code to access the second element in the list ['a', 'b', 'c', 'd']
word = ['a', 'b', 'c', 'd']
second_element = word[1]
print(second_element)
# Out:
# b

# %%
#10 Write a code to reverse the list [10, 20, 30, 40, 50].
listt=[10,20,30,40,50]
listt.reverse()
print(listt)
# Out:
# [50, 40, 30, 20, 10]

# %%
#11. Write a code to create a tuple with the elements 10, 20, 30 and print it.
element = (10,20,30)
print(element)
# Out:
# (10, 20, 30)

# %%
#12. Write a code to access the first element of the tuple ('apple', 'banana', 'cherry').
fruit = ("apple","banaba","chhery")
access = fruit[0]
print(access)
# Out:
# apple

# %%
#13. Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2).
number= (1,2,3,2,4,2)
number.count(2)
# Out:
# 3

# %%
#14. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').
element=("dog","cat","rabbit")
element.index("cat")
# Out:
# 1

# %%
#15. Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana')
fruit = ("apple","orange","banana")
present = "banana" in fruit
print(present)
# Out:
# True

# %%
#16. Write a code to create a set with the elements 1, 2, 3, 4, 5 and print it.
number={1,2,3,4,5}
print(number)
# Out:
# {1, 2, 3, 4, 5}

# %%
#17. Write a code to add the element 6 to the set {1, 2, 3, 4}.
number= {1,2,3,4}
number.add(6)
print(number)
# Out:
# {1, 2, 3, 4, 6}

# %%
#18. Write a code to create a tuple with the elements 10, 20, 30 and print it.
number= (10,20,30)
print(number)
# Out:
# (10, 20, 30)

# %%
 # 19. Write a code to access the first element of the tuple ('apple', 'banana', 'cherry').
fruit = ('apple', 'banana', 'cherry')
access = fruit[1]
print(access)
# Out:
# banana

# %%
#20. Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2).
number= (1,2,3,2,4,2)
number.count(2)
# Out:
# 3

# %%
# 21. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').
element=("dog","cat","rabbit")
element.index("cat")
# Out:
# 1

# %%
#22. Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana').
fruit = ("apple","orange","banana")
present = "banana" in fruit
print(present)
# Out:
# True

# %%
#23. Write a code to create a set with the elements 1, 2, 3, 4, 5 and print it.
number={1,2,3,4,5}
print(number)
# Out:
# {1, 2, 3, 4, 5}

# %%
#24. Write a code to add the element 6 to the set {1, 2, 3, 4}
number= {1,2,3,4}
number.add(6)
print(number)
# Out:
# {1, 2, 3, 4, 6}
